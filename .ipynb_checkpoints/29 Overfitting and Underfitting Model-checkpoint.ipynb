# %% [raw]
# MOdel >> Generalize Model (Training Acc & Testing Acc) almost
#
# Variance  >> measure the difference on different training data sets
#
# Bais >> Bais is model prediction differes from your target value

# %% [raw]
# 1000 rows and 5 columns
#
#
# Training(80%) :
#     800 rows x 5 columns
#
# Testing (20): [Unseen]
#     200 rows x 5 columns
#
#
# MOdel Training >> Training Data

# %% [markdown]
# # Overfitting

# %% [raw]
# Model Accuracy should 96%
# Training Accuracy (95%)
# Testing Accurcy (60%)
#
# Bais >> Low Bais
# Variance >> High Variance
#
#
# Overfitting >> Low Bais And High Variance

# %% [markdown]
# # Underfitting

# %% [raw]
# Model Accuracy >> 95%
# Training Accuracy >> low (70%)
# Testing Accuracy >> low(69%)
#
# Bais >> High Bias
# Variance >> low Variance
#
#
#
# ##################################
# Model Accuracy >> 90%
#
# Training Accuracy >> low (65%)
# Testing Accuracy >> low (45%)
#
# Bais >> High Bais
# Variance >> High Variance

# %% [markdown]
# # Best Model

# %% [raw]
# [2-3%] difference
#
# Model Accuracy should 96%
#
# Training Accuracy  >> High (95%)
# Testing Accuracy >> High (94%)
#
# Bias >> low Bias
# variance >> low variance
#
#
# Best Model or Generalize Model >> Low Bias and Low Variance

# %% [markdown]
# # trade off Bias and Variance

# %% [raw]
# Bias and Variance are inversely connected

# %% [markdown]
# ![image.png](attachment:feab82d1-9012-4346-9693-07ffb1d44fb0.png)

# %% [raw]
# Model Accuracy Should 90%
#
# training Acc >> low 70%
# testing Acc >> high 90%
#
#
# Bais >> high Bais
# Variance >> high variance
#
# underfit
