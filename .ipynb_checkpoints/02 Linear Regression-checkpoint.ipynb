# %% [raw]
# Regression:
#     Predicting a continuous value of the output variable.
#
# Classification:
#     predicting the category of the output variable.

# %% [raw]
# Output Feature: (this is the one we are intresting in predicting)  - (Y)
#     dependent feature/targeted column
#
# Input Feature:(this is provide to the model for predicting) --- (X1,X2,X3,X4....)
#     Indepndent Variable

# %% [raw]
# Linear Regression:
# 	- Linear Regression is a machine learning algorithm that falls under supervised learning.
# 	- Linear regression is a basic and commonly used type of predictive analysis.
#     - The model basically describe the relationship between the targeted column & the input columns by fitting a line on the observed data.
#     - the target variable is linearly related to the input variable.
#     - It is also called as ordinary least squared algorithm.
# 	- Linear regression is a linear model, e.g. a model that assumes a linear relationship between the input variables (x) and the single output variable (y). More specifically, that y can be calculated from a linear combination of the input variables (x).

# %% [markdown]
# # Types of Linear Regression

# %% [raw]
# 1. Simple Linear Regression [single line]
#     Equation:
#         y = mx + c
#
#         m >> slope
#         c >> intercept
#         x >> input Variable
#         y >> output
#
# 2. Multiple Linear Regression [Multiple lines]
#     Equation:
#         y = m1x1 + m2x2 + m3x3 ....... mNxN + c
#
#         m >> slope
#         c >> intercept
#         x1, x2....xN >> input Variable
#         y >> output

# %% [raw]
# Multinomial Regression:
#     - when we have more than 1 input variable for a linear regression then it would be called as multinomial regression.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Equation of a straight line:
#
#     y = mx + c
#
#     where,
#         m is the slope/angle of inclination,
#         c is the intercept on y axis
#         x is independent variable
#         y is dependet variable

# %% [raw]
# m = sum((x-xm)(y-ym))/(sum(x-xm)**2)

# %% [raw]
# best fit line : linear regression Predicted line
#
#     is that line which is closest to the maximum data points on the graph.
#     This is also called as regression line
#     best fit line always passes through mean point.

# %% [markdown]
# ## How does a best fit line is found by machine?

# %% [raw]
# - The best fit line in linear regression model is obtained by eq. y=mx+c where y is dependent variable, x is independent variable, m is slope of the best fit line & c is the intercept on y axis.
# - The best fit line always passes through the mean point.
# - Ones we fit the model into linear regression then in backend it uses gradient decent algorithm which in itself uses bond driver algorithm using which it finds global minima point which gives up exact values of m.

# %% [markdown]
# ## how to evaluate a regression model

# %% [raw]
# Higher the MSE or RMSE or MAB, poor is the model performing.
# MSE should be as less as possible.

# %% [markdown]
# ### Mean Squared Error

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Root Mean Squarefd Error:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Absolute Mean Squared Error

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![error.jpeg](attachment:a6687191-f232-4859-bb3e-b27e3ac80aa4.jpeg)

# %% [raw]
# SST >> Sum of Squared of Totol error >> sum(Y_actual-Y_mean)**2
# SSE >> Sum of Squared of Residual Error >> sum(Y_actual - Y_pred)**2
# SSR >> Sum of Squared of Regression Error  >> sum(Y_pred - Y_mean)**2

# %% [markdown]
# ### R Squared

# %% [raw]
# R_squared   = 1 - SSE/SST
#             = 1 - Sum of Square of Residual Error/Sum of Square of Total Error
#
# also called as coefficient of Determination

# %% [raw]
# R squared value can never negative in actual scenarios.
# however only in cases when for most of the points SSE is greater than SST we get R^2 -ve
# It is only possible when the best fit line is worst than the mean line.
# R Squared value can be negative when the chosen model does not follow the trend of the data or the model
# is not able to understand the underlying pattern of the data.
# In real life scenarios, you'll never have the r squared value goto be negative.

# %% [markdown]
# ### What are the flaws in R-squared?

# %% [raw]
# 1. Value of R^2 improves with good relationships as in the variables having strong correlation with targeted variable. But it also improves with fluke relationships. i.e. with variables having bad correlation with targeted variable.
#
# 2. This makes it comparatively less reliable than adjusted R squared value.
# Adjusted R2 improves with good relationships as in the variables having strong correlation with targeted variable. Bt it decreases every time for any fluke relationships. i.e. with variables having bad correlation with targeted variable.
#
# The formula for Adjusted R2 is-

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Note: Number of Predictors are the number of columns
#     Sample size is total number of obervations

# %% [markdown]
# ## Correlation

# %% [raw]
# It tells us about how well the independent & the dependent features are related.
#
# The value of R Varies from -1 to 1
# For R to be good:
#     R > 0.7
#     R < -0.7
#     other wise the corelation is bad.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Adjusted R^2

# %% [raw]
# R2 = 0.85
# Adj R2 = 0.85
#
# Case 1 : Added Good Predictor (R > 0.7 or R < -0.7)  >> correlated feature
#         R2 : 0.87
#         Adj R2: 0.87
#
# Case 2 : Added Bad Predictor (R < 0.7 or R > -0.7)  >> Non-correlated feature
#         R2 : 0.86
#         Adj R2: 0.84
#
#
# The value of adjusted R2 increases only for Good Predictor. For Bad predictor the value decreases.
#
# Adj R2 = 1 - ((1-R2)*(N-1)/(N-P-1))

# %% [markdown]
# ## Variance

# %% [raw]
# Variance is the spread of the total data points on the graph.
#
# If the spread is high (the data points are spread all over the graph) then we say Variance is high.
# If the spread is low (the data points are closely spread over the graph) then we say Variance is low.
#
# If the variance increases then the accuracy of the model would decrease & voice versa.
#
# Var = sum(Xi-Xm)**2 / N
#
# where,
#     sum = summation
#     Xi = Actual Points
#     Xm = Mean of all the Actual points
#     N = No. of points (population)

# %% [markdown]
# ## Standard Deviation

# %% [raw]
# Standard Deviation (STD) :
#
#     It explains how far the data points are from the mean point.
#     It is simply the square root of Variance
#     It also explains how much proportion of the data is how many std away.

# %% [raw]
# ### IMP Formula
#
#
# Residul/ Error = (Actual - Predicted)
#
# SSE/RSS = Σ(actaul - predicted)^2
# MSE = Σ(actaul - predicted)^2 / N
# SSR = Σ(predicted - mean)^2
# SST = Σ(actual - mean)^2  = SSR + SSE
# R-squared = 1 - (SSE/SST)

# %% [raw]
# All Assumptions are of Data
#
# 1. Linearity:
#
#     A linear realtion exist between input variable [independent] [x] and output [dependent] [y]
#
#     to check assumption >> scatter plot, df.corr
#
# 2. Independance (AutoCorreltion):
#     All input varibale [independent] should be independant to each other.
#
# 3. No Multicollinerity:
#     There should not be strong relation between each input variable
#
#     to check>> Coefficient of correlation (r) >> -1 to +1
#
#     if value of r greater than 0.7 or  less than -0.7 >> strongly correlated
#         value of r 0.3 to -0.3 >> random distribution
#         -1    -0.7     -0.3     0     0.3        0.7    +1
#         -|----||--------||------|-----||---------||----|--
#     to check visually >> pairplot
#
#
# 4. Normality:
#     All Error or Residuls should normally distributed.
#
# 5. Homoscedisticity :
#     the Erros or residuals must have constant variance.

# %% [markdown]
# ![image.png](attachment:255a9eae-2660-4fea-b9d8-22dc386e8e31.png)

# %% [markdown]
# ## Covariance

# %% [markdown]
# ![image.png](attachment:170d61af-d9c1-4998-9fe0-4469bc387e53.png)

# %% [raw]
# Positive Cov(x,y) = x & y are directly proportional
#
# x increase as y increase
#
#
# Negative Cov(x,y) = x & y are inversly proporational
#
# x increase as y decrease
#
#
# Zero (Approx) Cov(x,y) = Randomly distribute

# %% [raw]
# ### IMP Formula
#
#
# Residul/ Error = (Actual - Predicted)
#
# SSE/RSS = Σ(actaul - predicted)^2
# MSE = Σ(actaul - predicted)^2 / N
# SSR = Σ(predicted - mean)^2
# SST = Σ(actual - mean)^2  = SSR + SSE
# R-squared = 1 - (SSE/SST)
